# %% [markdown]
# This is a Lotto Simulator. Here you will find a simulation of the EuroJackpot.
# EuroJackpot takes 5 numbers from 1 to 50 and 2 numbers from 1 to 12

# %%
#spielzahlen = input("Choose 5 numbers from 1 to 50 to play")
#spielzahlen = spielzahlen.split()
print('spielzahlen')
